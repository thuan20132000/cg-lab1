# %% [markdown]
# # Tests
#
# This notebook contains basic sanity checks for the lab.

# %%
print("All tests passed.")
# Out:
# All tests passed.

# %%
# Basic sanity checks

def run_tests():
    # Replace with real assertions as lab requirements are added.
    assert True

run_tests()
print("All tests passed.")
# Out:
# All tests passed.
